# %% [markdown]
# # Laboratório 2

# %% [markdown]
# ## Tarefa 1
#
# ### Carregue o nó de Tenda dos Milagres (da versão em inglês Tent of Miracles) em Python e mostre o conteúdo JSON.

# %%
import io
import requests
import json
url_drum = "https://dbpedia.org/data/Tent_of_Miracles_(novel).jsod"
js_drum = requests.get(url_drum)
print(js_drum.content.decode("utf-8"))
# Out:
# { "d" : {
#   "results": [
#     { "__metadata": { "uri": "http://dbpedia.org/resource/Tent_of_Miracles_(novel)" },
#       "http://www.w3.org/2000/01/rdf-schema#label": "Tenda dos Milagres (romance)",
#       "http://dbpedia.org/ontology/wikiPageWikiLink": { "__deferred": { "uri": "http://dbpedia.org/resource/Category:Brazilian_novels" } },
#       "http://purl.org/dc/terms/subject": { "__deferred": { "uri": "http://dbpedia.org/resource/Category:Brazilian_novels" } },
#       "http://www.w3.org/1999/02/22-rdf-syntax-ns#type": { "__deferred": { "uri": "http://dbpedia.org/class/yago/Abstraction100002137" } },
#       "http://dbpedia.org/property/wikiPageUsesTemplate": { "__deferred": { "uri": "http://dbpedia.org/resource/Template:Infobox_book" } },
#       "http://www.w3.org/1999/02/22-rdf-syntax-ns#type": { "__deferred": { "uri": "http://www.wikidata.org/entity/Q571" } },
#       "http://www.w3.org/1999/02/22-rdf-syntax-ns#type": { "__deferred": { "uri": "http://dbpedia.org/class/yago/Wikicat1969Novels" } },
#       "http://www.w3.org/1999/02/22-rdf-syntax-ns#type": { "__deferred": { "uri": "http://www.wikidata.org/entity/Q234460" } },
#       "http://www.w3.org/1999/02/22-rdf-syntax-ns#type": { "__deferred": { "uri": "http://dbpedia.org/class/yago/WikicatNovelsByJorgeAmado" } },
#       "http://dbpedia.org/ontology/wikiPageWikiLink": { "__deferred": { "uri": "http://dbpedia.org/resource/Category:Novels_set_in_Salvador,_Bahia" } },
#       "http://www.w3.org/2000/01/rdf-schema#comment": "Лавка чудес — роман Жоржи Амаду в жанре магического реализма, написанный в середине 1960-х годов. Основная тема романа — исследование смешения культур и расизма в Бразилии. В 1977 году роман был экранизирован Нелсоном Перейрой дос Сантосом по сценарию самого Амаду. В 1985 году по роману был поставлен небольшой сериал (30 серий). По мнению Ю. Покальчука, является одним из самых программных произведений автора.",
#       "http://www.w3.org/2000/01/rdf-schema#label": "La bottega dei miracoli",
#       "http://dbpedia.org/ontology/abstract": "Tenda dos Milagres é um romance do escritor brasileiro Jorge Amado, publicado em 1969. Esta obra serviu de base, ainda para adaptações, no cinema e na televisão, além de merecer traduções em alemão, árabe, búlgaro, espanhol, finlandês, francês, húngaro, inglês, italiano, russo e turco.",
#       "http://www.w3.org/1999/02/22-rdf-syntax-ns#type": { "__deferred": { "uri": "http://dbpedia.org/class/yago/WikicatPortuguese-languageNovels" } },
#       "http://dbpedia.org/property/pubDate": "1969",
#       "http://www.w3.org/2000/01/rdf-schema#label": "Лавка чудес (роман)",
#       "http://www.w3.org/1999/02/22-rdf-syntax-ns#type": { "__deferred": { "uri": "http://schema.org/Book" } },
#       "http://dbpedia.org/property/country": { "__deferred": { "uri": "http://dbpedia.org/resource/Brazil" } },
#       "http://www.w3.org/2002/07/owl#sameAs": { "__deferred": { "uri": "http://ru.dbpedia.org/resource/Лавка_чудес_(роман)" } },
#       "http://www.w3.org/2002/07/owl#sameAs": { "__deferred": { "uri": "https://global.dbpedia.org/id/Qk3p" } },
#       "http://www.w3.org/1999/02/22-rdf-syntax-ns#type": { "__deferred": { "uri": "http://dbpedia.org/class/yago/LiteraryComposition106364329" } },
#       "http://dbpedia.org/ontology/wikiPageRevisionID": "974212123",
#       "http://www.w3.org/1999/02/22-rdf-syntax-ns#type": { "__deferred": { "uri": "http://dbpedia.org/class/yago/Fiction106367107" } },
#       "http://dbpedia.org/ontology/wikiPageWikiLink": { "__deferred": { "uri": "http://dbpedia.org/resource/Brazil" } },
#       "http://www.w3.org/1999/02/22-rdf-syntax-ns#type": { "__deferred": { "uri": "http://dbpedia.org/class/yago/Communication100033020" } },
#       "http://dbpedia.org/property/wikiPageUsesTemplate": { "__deferred": { "uri": "http://dbpedia.org/resource/Template:Attribution_needed" } },
#       "http://www.w3.org/1999/02/22-rdf-syntax-ns#type": { "__deferred": { "uri": "http://dbpedia.org/class/yago/Writing106362953" } },
#       "http://dbpedia.org/ontology/wikiPageWikiLink": { "__deferred": { "uri": "http://dbpedia.org/resource/Category:1969_novels" } },
#       "http://www.w3.org/1999/02/22-rdf-syntax-ns#type": { "__deferred": { "uri": "http://www.w3.org/2002/07/owl#Thing" } },
#       "http://dbpedia.org/property/author": { "__deferred": { "uri": "http://dbpedia.org/resource/Jorge_Amado" } },
#       "http://dbpedia.org/ontology/wikiPageWikiLink": { "__deferred": { "uri": "http://dbpedia.org/resource/Salvador,_Bahia" } },
#       "http://purl.org/dc/terms/subject": { "__deferred": { "uri": "http://dbpedia.org/resource/Category:Portuguese-language_novels" } },
#       "http://dbpedia.org/ontology/wikiPageWikiLink": { "__deferred": { "uri": "http://dbpedia.org/resource/Tenda_dos_Milagres_(film)" } },
#       "http://www.w3.org/1999/02/22-rdf-syntax-ns#type": { "__deferred": { "uri": "http://dbpedia.org/ontology/Book" } },
#       "http://dbpedia.org/property/wikiPageUsesTemplate": { "__deferred": { "uri": "http://dbpedia.org/resource/Template:Jorge_Amado" } },
#       "http://dbpedia.org/ontology/author": { "__deferred": { "uri": "http://dbpedia.org/resource/Jorge_Amado" } },
#       "http://xmlns.com/foaf/0.1/name": "Tent of Miracles",
#       "http://www.w3.org/2002/07/owl#sameAs": { "__deferred": { "uri": "http://yago-knowledge.org/resource/Tent_of_Miracles_(novel)" } },
#       "http://dbpedia.org/ontology/wikiPageWikiLink": { "__deferred": { "uri": "http://dbpedia.org/resource/Portuguese_language" } },
#       "http://dbpedia.org/property/englishPubDate": "1971",
#       "http://dbpedia.org/ontology/wikiPageWikiLink": { "__deferred": { "uri": "http://dbpedia.org/resource/Modernism" } },
#       "http://dbpedia.org/ontology/country": { "__deferred": { "uri": "http://dbpedia.org/resource/Brazil" } },
#       "http://www.w3.org/1999/02/22-rdf-syntax-ns#type": { "__deferred": { "uri": "http://dbpedia.org/class/yago/WikicatBrazilianNovels" } },
#       "http://www.w3.org/1999/02/22-rdf-syntax-ns#type": { "__deferred": { "uri": "http://purl.org/ontology/bibo/Book" } },
#       "http://dbpedia.org/ontology/abstract": "Tent of Miracles (Portuguese: Tenda dos Milagres) is a Brazilian Modernist novel. It was written by Jorge Amado in 1967 and published the following year. It was later adapted to a 1977 Cinema Novo (Nouvelle Vague) film by director/screenplay writer Nelson Pereira dos Santos. Tent of Miracles was written three years after the military overthrew Brazilian democracy, and it is part of a series Amado called &quot;The Bahia Novels&quot;, works exploring the region&#39;s past. The novel chronicles the chaos that results when a prominent Columbia University professor arrives in Brazil, with nothing but praise on his lips for a long-forgotten local Bahian writer and self-taught social scientist named Pedro Archanjo. The year is 1968, which Levinson announces is the centennial of Archanjo&#39;s birth, setting off a media stampede to figure out who Archanjo was so that they can profit from a celebration of his life. When a few people finally uncover who Arcanjo was and what he espoused, media barons and advertisers are horrified to discover that he was an Afro-Brazilian social critic, womanizer and heavy drinker who died penniless in the gutter. So, they invent their own Pedro Archanjo, which they hype in various advertising-driven events, enlisting some Brazilian academics who are as superficial and self-promoting as Levinson. The novel moves back and forth between events in the life of the historical hero, Pedro Archanjo, and the present. Most of the characters are types that lend themselves to the author&#39;s relentless satire. The historical setting is the colorful old Pelourinho neighborhood of Salvador, Bahia, that flows down the hill from the main plaza, where Archanjo works as a lowly runner at the School of Medicine adjacent to the cathedral. The place of the title is the home of the hero and his best friend, Lidio Corro, which also serves as barber shop, cultural center, print shop and artist&#39;s studio. The historical sections explore Afro-Brazilian culture and racial discrimination. Author Jorge Amado once declared that &quot;Brazil is a racial democracy&quot;, and the novel is consistent with that belief, because he situates all racism in the past. The hero&#39;s male children are all over the city, but he is father to none. They call him &quot;godfather,&quot; and he takes one of his &quot;godchildren,&quot; Tadeu, under his wing to help him pursue an engineering degree. The womanizing of the hero serves to highlight the belief of both Pedro Archanjo and the novel&#39;s author that uninhibited sexual passion between people of different races and colors (and the resulting mixed children) is Brazil&#39;s unique solution to racism. The theory behind this view was disseminated by Brazilian sociologist and historian Gilberto Freyre in his treatise Casa-Grande &amp; Senzala (1933), translated into English as The Masters and the Slaves. A number of the female characters in the novel are highly sexualized in ways that, according to critics, represent racial stereotypes. In the face of criticism of his portrayals of women and Afro-Brazilian culture, Jorge Amado declared: &quot;It is not a question of literary pride. It is only the certainty that no one until today had dared to look face-to-face with so much love at Bahian humanity and its problems. No one knows better than I, who wrote them, what the weaknesses and defects of my novels are. But, by the same token, no one can measure the sacrifice they cost me, the honesty that went into their making, the disinterest and pure love that made the novelist return to his people.&quot; Beyond Amado&#39;s treatment of women and Afro-Brazilian culture, Tent of Miracles is a powerful satire of modern Brazilian institutions, especially the mass media and parts of academia. Notably spared from the author&#39;s knife is the Brazilian military, which in 1967 was detaining, torturing and exiling some of Amado&#39;s political friends. A few schola ...
#       "http://www.w3.org/2002/07/owl#sameAs": { "__deferred": { "uri": "http://pt.dbpedia.org/resource/Tenda_dos_Milagres_(romance)" } },
#       "http://www.w3.org/2000/01/rdf-schema#comment": "La bottega dei miracoli è un romanzo di Jorge Amado pubblicato nel 1960. Come altri romanzi dell&#39;autore (ad esempio Tieta d&#39;Agreste e Teresa Batista) è un testo composito, con un intreccio zigzagante fra analessi e prolessi, con mutamenti di voci narranti ed inserti di materiale eterogeneo.È possibile che l&#39;evento scatenante del racconto (la visita del famoso scienziato) sia stato ispirato dall&#39;esperienza vissuta; in quello stesso 1960, infatti, Jean Paul Sartre e Simone De Beauvoir visitarono il Brasile su invito dello stesso Amado: la visita divenne un evento mediatico, celebrato in numerose manifestazioni istituzionali.",
#       "http://dbpedia.org/property/name": "Tent of Miracles",
#       "http://dbpedia.org/ontology/abstract": "Лавка чудес — роман Жоржи Амаду в жанре магического реализма, написанный в середине 1960-х годов. Основная тема романа — исследование смешения культур и расизма в Бразилии. В 1977 году роман был экранизирован Нелсоном Перейрой дос Сантосом по сценарию самого Амаду. В 1985 году по роману был поставлен небольшой сериал (30 серий). По мнению Ю. Покальчука, является одним из самых программных произведений автора.",
#       "http://purl.org/dc/terms/subject": { "__deferred": { "uri": "http://dbpedia.org/resource/Category:1969_novels" } },
#       "http://purl.org/linguistics/gold/hypernym": { "__deferred": { "uri": "http://dbpedia.org/resource/Novel" } },
#       "http://dbpedia.org/property/titleOrig": "Tenda dos Milagres",
#       "http://dbpedia.org/ontology/wikiPageWikiLink": { "__deferred": { "uri": "http://dbpedia.org/resource/Jorge_Amado" } },
#       "http://dbpedia.org/property/wikiPageUsesTemplate": { "__deferred": { "uri": "http://dbpedia.org/resource/Template:Short_description" } },
#       "http://dbpedia.org/ontology/publisher": { "__deferred": { "uri": "http://dbpedia.org/resource/Brazil" } },
#       "http://dbpedia.org/ontology/language": { "__deferred": { "uri": "http://dbpedia.org/resource/Portuguese_language" } },
#       "http://dbpedia.org/ontology/abstract": "La bottega dei miracoli è un romanzo di Jorge Amado pubblicato nel 1960. Come altri romanzi dell&#39;autore (ad esempio Tieta d&#39;Agreste e Teresa Batista) è un testo composito, con un intreccio zigzagante fra analessi e prolessi, con mutamenti di voci narranti ed inserti di materiale eterogeneo.È possibile che l&#39;evento scatenante del racconto (la visita del famoso scienziato) sia stato ispirato dall&#39;esperienza vissuta; in quello stesso 1960, infatti, Jean Paul Sartre e Simone De Beauvoir visitarono il Brasile su invito dello stesso Amado: la visita divenne un evento mediatico, celebrato in numerose manifestazioni istituzionali.",
#       "http://dbpedia.org/ontology/wikiPageWikiLink": { "__deferred": { "uri": "http://dbpedia.org/resource/Category:Portuguese-language_novels" } },
#       "http://purl.org/dc/terms/subject": { "__deferred": { "uri": "http://dbpedia.org/resource/Category:Novels_by_Jorge_Amado" } },
#       "http://dbpedia.org/ontology/wikiPageWikiLink": { "__deferred": { "uri": "http://dbpedia.org/resource/Cinema_Novo" } },
#       "http://www.w3.org/ns/prov#wasDerivedFrom": { "__deferred": { "uri": "http://en.wikipedia.org/wiki/Tent_of_Miracles_(novel)?oldid=974212123&ns=0" } },
#       "http://dbpedia.org/ontology/wikiPageWikiLink": { "__deferred": { "uri": "http://dbpedia.org/resource/Novel" } },
#       "http://dbpedia.org/ontology/wikiPageLength": "5253",
#       "http://www.w3.org/2002/07/owl#sameAs": { "__deferred": { "uri": "http://it.dbpedia.org/resource/La_bottega_dei_miracoli" } },
#       "http://purl.org/dc/elements/1.1/publisher": "Martins, Sao Paulo, Brazil",
#       "http://dbpedia.org/property/language": { "__deferred": { "uri": "http://dbpedia.org/resource/Portuguese_language" } },
#       "http://xmlns.com/foaf/0.1/name": "Tenda dos Milagres",
#       "http://www.w3.org/2002/07/owl#sameAs": { "__deferred": { "uri": "http://www.wikidata.org/entity/Q140000" } },
#       "http://purl.org/dc/terms/subject": { "__deferred": { "uri": "http://dbpedia.org/resource/Category:Novels_set_in_Salvador,_Bahia" } },
#       "http://www.w3.org/2000/01/rdf-schema#comment": "Tenda dos Milagres é um romance do escritor brasileiro Jorge Amado, publicado em 1969. Esta obra serviu de base, ainda para adaptações, no cinema e na televisão, além de merecer traduções em alemão, árabe, búlgaro, espanhol, finlandês, francês, húngaro, inglês, italiano, russo e turco.",
#       "http://dbpedia.org/ontology/wikiPageID": "623351",
#       "http://www.w3.org/1999/02/22-rdf-syntax-ns#type": { "__deferred": { "uri": "http://dbpedia.org/class/yago/WikicatModernistNovels" } },
#       "http://www.w3.org/2000/01/rdf-schema#comment": "Tent of Miracles (Portuguese: Tenda dos Milagres) is a Brazilian Modernist novel. It was written by Jorge Amado in 1967 and published the following year. It was later adapted to a 1977 Cinema Novo (Nouvelle Vague) film by director/screenplay writer Nelson Pereira dos Santos.",
#       "http://dbpedia.org/ontology/wikiPageWikiLink": { "__deferred": { "uri": "http://dbpedia.org/resource/Nelson_Pereira_dos_Santos" } },
#       "http://dbpedia.org/ontology/wikiPageWikiLink": { "__deferred": { "uri": "http://dbpedia.org/resource/Category:Novels_by_Jorge_Amado" } },
#       "http://dbpedia.org/ontology/wikiPageWikiLink": { "__deferred": { "uri": "http://dbpedia.org/resource/Category:Modernist_novels" } },
#       "http://www.w3.org/2000/01/rdf-schema#label": "Tent of Miracles (novel)",
#       "http://dbpedia.org/ontology/wikiPageWikiLink": { "__deferred": { "uri": "http://dbpedia.org/resource/Casa-Grande_&_Senzala" } },
#       "http://purl.org/dc/terms/subject": { "__deferred": { "uri": "http://dbpedia.org/resource/Category:Modernist_novels" } },
#       "http://www.w3.org/1999/02/22-rdf-syntax-ns#type": { "__deferred": { "uri": "http://dbpedia.org/class/yago/Novel106367879" } },
#       "http://www.w3.org/1999/02/22-rdf-syntax-ns#type": { "__deferred": { "uri": "http://dbpedia.org/class/yago/WrittenCommunication106349220" } },
#       "http://dbpedia.org/property/wikiPageUsesTemplate": { "__deferred": { "uri": "http://dbpedia.org/resource/Template:According_to_whom" } },
#       "http://www.w3.org/1999/02/22-rdf-syntax-ns#type": { "__deferred": { "uri": "http://www.wikidata.org/entity/Q386724" } },
#       "http://www.w3.org/1999/02/22-rdf-syntax-ns#type": { "__deferred": { "uri": "http://dbpedia.org/ontology/Work" } },
#       "http://dbpedia.org/ontology/wikiPageWikiLink": { "__deferred": { "uri": "http://dbpedia.org/resource/French_New_Wave" } },
#       "http://dbpedia.org/property/publisher": "Martins, Sao Paulo, Brazil",
#       "http://www.w3.org/2002/07/owl#sameAs": { "__deferred": { "uri": "http://tr.dbpedia.org/resource/Mucizeler_Dükkânı" } },
#       "http://dbpedia.org/property/caption": "First edition",
#       "http://xmlns.com/foaf/0.1/isPrimaryTopicOf": { "__deferred": { "uri": "http://en.wikipedia.org/wiki/Tent_of_Miracles_(novel)" } },
#       "http://www.w3.org/1999/02/22-rdf-syntax-ns#type": { "__deferred": { "uri": "http://schema.org/CreativeWork" } },
#       "http://www.w3.org/1999/02/22-rdf-syntax-ns#type": { "__deferred": { "uri": "http://dbpedia.org/ontology/WrittenWork" } },
#       "http://www.w3.org/2002/07/owl#sameAs": { "__deferred": { "uri": "http://rdf.freebase.com/ns/m.02xrs4" } }
#      }
#  ], "__count": "1"
#  } }

# %% [markdown]
# ## Tarefa 2
# ### Recupere via Python e mostre o autor de Tenda dos Milagres?

# %%
json_drum = js_drum.json()
url_grass = json_drum["d"]["results"][0]["http://dbpedia.org/ontology/author"]["__deferred"]["uri"]
print("Autor de Tent of Miracles: " + url_grass)
# Out:
# Autor de Tent of Miracles: http://dbpedia.org/resource/Jorge_Amado

# %% [markdown]
# ## Tarefa 3
# ### Quais os termos usados para Aspirina (consulta JSON/MeSH em Python)?

# %%
url_template = "https://id.nlm.nih.gov/mesh/lookup/descriptor?label={concept}&match={match}&limit={limit}"

concept = "Aspirin"
match = "exact"
limit = "10"

concept = concept.replace(" ", "%20")

url = url_template.replace("{concept}", concept)\
                  .replace("{match}", match)\
                  .replace("{limit}", limit)

data = requests.get(url)
json_mi = data.json()
print(json.dumps(json_mi, indent=3))
# Out:
# [
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/D001241",
#       "label": "Aspirin"
#    }
# ]

# %%
uri_mesh = json_mi[0]["resource"]
print("uri do recurso: " + uri_mesh)
bar = str.rindex(uri_mesh, "/")
print("código do recurso: " + uri_mesh[bar+1:])
# Out:
# uri do recurso: http://id.nlm.nih.gov/mesh/D001241
# código do recurso: D001241

# %%
url_template = "https://id.nlm.nih.gov/mesh/lookup/details?descriptor={code}"

code = uri_mesh[bar+1:]

url = url_template.replace("{code}", code)

data = requests.get(url)
json_mid = data.json()
print(json.dumps(json_mid["terms"], indent=3))
# Out:
# [
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003713",
#       "label": "Aspirin",
#       "preferred": true
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003714",
#       "label": "2-(Acetyloxy)benzoic Acid",
#       "preferred": false
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003712",
#       "label": "Acetylsalicylic Acid",
#       "preferred": false
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003721",
#       "label": "Acetysal",
#       "preferred": false
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003722",
#       "label": "Acylpyrin",
#       "preferred": false
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003711",
#       "label": "Aloxiprimum",
#       "preferred": false
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003723",
#       "label": "Colfarit",
#       "preferred": false
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003715",
#       "label": "Dispril",
#       "preferred": false
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003719",
#       "label": "Easprin",
#       "preferred": false
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003724",
#       "label": "Ecotrin",
#       "preferred": false
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003725",
#       "label": "Endosprin",
#       "preferred": false
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003726",
#       "label": "Magnecyl",
#       "preferred": false
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003727",
#       "label": "Micristin",
#       "preferred": false
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003717",
#       "label": "Polopirin",
#       "preferred": false
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003728",
#       "label": "Polopiryna",
#       "preferred": false
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003716",
#       "label": "Solprin",
#       "preferred": false
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003718",
#       "label": "Solupsan",
#       "preferred": false
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003720",
#       "label": "Zorprin",
#       "preferred": false
#    }
# ]

# %% [markdown]
# ## Tarefa 4
# ### Escolha algum lugar no OpenStreetMap e elabore a mesma sequência de três chamadas de serviços para o seu conceito.

# %%
url_template = "http://nominatim.openstreetmap.org/search?format={format}&q={query}"
format = "json"
query = "Stanley Park"

url = url_template.replace("{format}", format)\
                  .replace("{query}", query)

data = requests.get(url)
park_ref = data.json()
print(json.dumps(park_ref, indent=3))
# Out:
# [
#    {
#       "place_id": 100494626,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "way",
#       "osm_id": 37063023,
#       "boundingbox": [
#          "49.2897635",
#          "49.3140822",
#          "-123.1596411",
#          "-123.1163629"
#       ],
#       "lat": "49.3019112",
#       "lon": "-123.14154052837662",
#       "display_name": "Stanley Park, West End, Vancouver, District of North Vancouver, Metro Vancouver Regional District, British Columbia, V6G, Canada",
#       "class": "leisure",
#       "type": "park",
#       "importance": 0.6478289508335251
#    },
#    {
#       "place_id": 84698754,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "way",
#       "osm_id": 4830204,
#       "boundingbox": [
#          "53.4308306",
#          "53.4376261",
#          "-2.968695",
#          "-2.9549827"
#       ],
#       "lat": "53.43438875",
#       "lon": "-2.962685779471351",
#       "display_name": "Stanley Park, Walton, Liverpool, North West England, England, United Kingdom",
#       "class": "leisure",
#       "type": "park",
#       "importance": 0.494548847777872
#    },
#    {
#       "place_id": 259532072,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "relation",
#       "osm_id": 9489750,
#       "boundingbox": [
#          "44.6271146",
#          "44.6343985",
#          "-63.6347652",
#          "-63.6237333"
#       ],
#       "lat": "44.6322063",
#       "lon": "-63.6290955",
#       "display_name": "Stanley Park, Halifax, Nova Scotia, Canada",
#       "class": "boundary",
#       "type": "administrative",
#       "importance": 0.45,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png"
#    },
#    {
#       "place_id": 3925397,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "node",
#       "osm_id": 472560239,
#       "boundingbox": [
#          "43.436187",
#          "43.456187",
#          "-80.4556112",
#          "-80.4356112"
#       ],
#       "lat": "43.446187",
#       "lon": "-80.4456112",
#       "display_name": "Stanley Park, Kitchener, Region of Waterloo, Southwestern Ontario, Ontario, N2A 1Y9, Canada",
#       "class": "place",
#       "type": "neighbourhood",
#       "importance": 0.45
#    },
#    {
#       "place_id": 381192,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "node",
#       "osm_id": 151724556,
#       "boundingbox": [
#          "39.5983213",
#          "39.6383213",
#          "-105.3127696",
#          "-105.2727696"
#       ],
#       "lat": "39.6183213",
#       "lon": "-105.2927696",
#       "display_name": "Stanley Park, Evergreen, Jefferson County, Colorado, United States",
#       "class": "place",
#       "type": "hamlet",
#       "importance": 0.45,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//poi_place_village.p.20.png"
#    },
#    {
#       "place_id": 231008468,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "way",
#       "osm_id": 705681365,
#       "boundingbox": [
#          "51.4975627",
#          "51.4992745",
#          "-2.5657697",
#          "-2.5619293"
#       ],
#       "lat": "51.498431",
#       "lon": "-2.5637558288579507",
#       "display_name": "Stanley Park, Stoke Gifford, South Gloucestershire, South West England, England, BS34, United Kingdom",
#       "class": "landuse",
#       "type": "residential",
#       "importance": 0.39999999999999997
#    },
#    {
#       "place_id": 307430409,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "way",
#       "osm_id": 265426907,
#       "boundingbox": [
#          "51.4458901",
#          "51.4513529",
#          "-2.0886258",
#          "-2.0829683"
#       ],
#       "lat": "51.449039299999995",
#       "lon": "-2.0862181359401495",
#       "display_name": "Stanley Park, Chippenham, Wiltshire, South West England, England, SN15, United Kingdom",
#       "class": "landuse",
#       "type": "recreation_ground",
#       "importance": 0.39999999999999997
#    },
#    {
#       "place_id": 181863411,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "way",
#       "osm_id": 393576152,
#       "boundingbox": [
#          "-43.8101852",
#          "-43.8086509",
#          "172.9652141",
#          "172.9677557"
#       ],
#       "lat": "-43.809438",
#       "lon": "172.96668259285173",
#       "display_name": "Stanley Park, Akaroa, Banks Peninsula Community, Christchurch City, Canterbury, New Zealand / Aotearoa",
#       "class": "landuse",
#       "type": "grass",
#       "importance": 0.39999999999999997
#    },
#    {
#       "place_id": 142797223,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "way",
#       "osm_id": 215333080,
#       "boundingbox": [
#          "-35.3994655",
#          "-35.3986894",
#          "149.0639756",
#          "149.0651669"
#       ],
#       "lat": "-35.3990796",
#       "lon": "149.06458300178247",
#       "display_name": "Stanley Park, Kambah, District of Tuggeranong, Australian Capital Territory, 2902, Australia",
#       "class": "landuse",
#       "type": "residential",
#       "importance": 0.39999999999999997
#    },
#    {
#       "place_id": 2642580,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "node",
#       "osm_id": 357796777,
#       "boundingbox": [
#          "35.3636978",
#          "35.3637978",
#          "-81.0901269",
#          "-81.0900269"
#       ],
#       "lat": "35.3637478",
#       "lon": "-81.0900769",
#       "display_name": "Stanley Park, Craig Heights, Stanley, Gaston County, North Carolina, 28164, United States",
#       "class": "leisure",
#       "type": "park",
#       "importance": 0.36000000000000004
#    }
# ]

# %%
print(park_ref[0]["osm_id"])
# Out:
# 37063023

# %%
url_template = "https://api.openstreetmap.org/api/0.6/{element_type}/{id}.{format}"

element_type = "way" # types: node, way, or relation
id = str(park_ref[0]["osm_id"])
format = "json"

url = url_template.replace("{element_type}", element_type)\
                  .replace("{id}", id)\
                  .replace("{format}", format)

data = requests.get(url)
park_way = data.json()
print(json.dumps(park_way, indent=3))
# Out:
# {
#    "version": "0.6",
#    "generator": "CGImap 0.8.5 (50441 spike-07.openstreetmap.org)",
#    "copyright": "OpenStreetMap and contributors",
#    "attribution": "http://www.openstreetmap.org/copyright",
#    "license": "http://opendatacommons.org/licenses/odbl/1-0/",
#    "elements": [
#       {
#          "type": "way",
#          "id": 37063023,
#          "timestamp": "2020-09-22T07:27:45Z",
#          "version": 38,
#          "changeset": 91271163,
#          "user": "DunbarLoop",
#          "uid": 2032374,
#          "nodes": [
#             268528858,
#             3673125464,
#             268528862,
#             39610354,
#             471726516,
#             471726511,
#             39631955,
#             471726512,
#             471726513,
#             471726514,
#             471726515,
#             39628755,
#             39582671,
#             471727685,
#             471727684,
#             39604745,
#             39600938,
#             39597610,
#             39622064,
#             471727682,
#             471727683,
#             39618646,
#             39615175,
#             1309735559,
#             39609403,
#             471727686,
#             1309735106,
#             1309735491,
#             471727687,
#             39637712,
#             39629583,
#             39626577,
#             1309735046,
#             39593057,
#             39589647,
#             1309734962,
#             1309735374,
#             1309734903,
#             1309735479,
#             1309735414,
#             39581829,
#             39605455,
#             39603510,
#             39599386,
#             39597431,
#             1309734947,
#             1309735359,
#             39621380,
#             1309734888,
#             1309734817,
#             1309735234,
#             39613641,
#             1309735729,
#             1309735188,
#             39616175,
#             1309735124,
#             39612265,
#             39630332,
#             1309735503,
#             39636541,
#             1309735623,
#             39630077,
#             39590850,
#             39593624,
#             39584508,
#             7037214517,
#             39585300,
#             1309735264,
#             1309735203,
#             39606501,
#             39595451,
#             39599813,
#             2926971059,
#             2926971058,
#             1002970176,
#             1309735159,
#             1309735419,
#             1309735013,
#             1002970175,
#             1002970172,
#             1002970170,
#             1002970168,
#             1002970164,
#             1002970160,
#             1002970156,
#             1002970143,
#             2926971060,
#             39640852,
#             1309734988,
#             1309735452,
#             1309735058,
#             1309735133,
#             1309735608,
#             1309735185,
#             1309734828,
#             1309734884,
#             39627622,
#             1309735300,
#             1309734974,
#             1309735441,
#             1309735045,
#             1309735117,
#             1309735587,
#             39604729,
#             1309735345,
#             1309734935,
#             1309735009,
#             1309735463,
#             1309735077,
#             39621799,
#             39614880,
#             1309735389,
#             39632028,
#             39625443,
#             1309735318,
#             39628971,
#             39592260,
#             39609803,
#             1309734844,
#             1309735258,
#             1309735771,
#             39613486,
#             1309735148,
#             1309735641,
#             39637278,
#             1309735532,
#             39590066,
#             1309735093,
#             39592898,
#             268528786,
#             39587546,
#             1309735164,
#             1309735563,
#             39606311,
#             1309735481,
#             1309735028,
#             1309735433,
#             39605729,
#             39581906,
#             1309734966,
#             39628514,
#             39631237,
#             39639320,
#             39609942,
#             268528787,
#             268528788,
#             1309735498,
#             39620328,
#             39602145,
#             39605431,
#             631421238,
#             631421237,
#             1309735511,
#             1309735128,
#             856091513,
#             1309735595,
#             39587398,
#             39590242,
#             39591492,
#             39626546,
#             39631738,
#             39639680,
#             39611530,
#             39615070,
#             1309735449,
#             39623021,
#             1309735142,
#             1309735071,
#             1309735458,
#             1309735002,
#             1309735410,
#             1309735339,
#             268528789,
#             1309734868,
#             1309735287,
#             39600994,
#             39604420,
#             1309735818,
#             39607460,
#             268528790,
#             1309735386,
#             1309735173,
#             39586601,
#             39592160,
#             629866065,
#             1309735548,
#             268528791,
#             1309735102,
#             630877380,
#             39610868,
#             39614409,
#             1309735023,
#             39619526,
#             5732531189,
#             1309735428,
#             5732531190,
#             630877387,
#             1309735370,
#             5732531188,
#             630877390,
#             5732531191,
#             1309734958,
#             630877393,
#             630877384,
#             39622140,
#             39597996,
#             39601195,
#             39605138,
#             39608370,
#             39583861,
#             39587152,
#             1309735301,
#             39588895,
#             39593038,
#             39625716,
#             39628942,
#             39631809,
#             39640537,
#             39613463,
#             268528792,
#             39617405,
#             1309734829,
#             1309735244,
#             39621217,
#             1309735317,
#             39596994,
#             1309735257,
#             39586264,
#             1309734842,
#             1309735197,
#             39605111,
#             1309735640,
#             1227312340,
#             1309735209,
#             1309734922,
#             1227312374,
#             39602192,
#             1227312350,
#             1309735262,
#             1227312380,
#             549653511,
#             268528793,
#             1227312362,
#             39619278,
#             1227312382,
#             39615947,
#             1227312345,
#             1227312352,
#             1227312388,
#             1227312337,
#             1227312348,
#             39609119,
#             1227312386,
#             39639215,
#             1227312344,
#             549653465,
#             39631593,
#             1227312335,
#             344868241,
#             1309735636,
#             344868240,
#             549653464,
#             1227312351,
#             39628423,
#             1227312361,
#             344868187,
#             1227312373,
#             344868200,
#             1227312333,
#             268528795,
#             1227312347,
#             344868201,
#             1227312372,
#             1227312336,
#             344868135,
#             268528796,
#             268528797,
#             1261280672,
#             344868528,
#             1261280667,
#             39626896,
#             39591520,
#             344868529,
#             39588264,
#             1309735509,
#             1309735070,
#             39587309,
#             344868530,
#             1261280690,
#             39584029,
#             344868531,
#             1261280678,
#             39629423,
#             39591884,
#             344868532,
#             1309734911,
#             39588353,
#             39585318,
#             39587585,
#             1309734985,
#             1309735313,
#             1309735384,
#             1309734970,
#             1309735436,
#             1309735038,
#             39584289,
#             39608092,
#             1309735113,
#             1309735573,
#             39605066,
#             1309735167,
#             1309735686,
#             39600883,
#             1261280684,
#             1261280681,
#             344868658,
#             1261280662,
#             39598640,
#             1309735804,
#             344868659,
#             268528798,
#             430960629,
#             3678463062,
#             2013083099,
#             346202802,
#             268528849,
#             7930474630,
#             268528850,
#             3673074116,
#             268528459,
#             471262864,
#             268528460,
#             539920756,
#             471262862,
#             539920752,
#             268528511,
#             268528855,
#             3675681165,
#             268528856,
#             268528857,
#             268528858
#          ],
#          "tags": {
#             "leisure": "park",
#             "name": "Stanley Park",
#             "name:be": "\u0421\u0442\u044d\u043d\u043b\u0456 \u041f\u0430\u0440\u043a",
#             "name:ko": "\uc2a4\ud0e0\ub9ac \uacf5\uc6d0",
#             "name:ru": "\u0421\u0442\u044d\u043d\u043b\u0438-\u043f\u0430\u0440\u043a",
#             "opening_hours": "Mo-Fr 09:00-17:00",
#             "website": "https://vancouver.ca/parks-recreation-culture/stanley-park.aspx",
#             "wheelchair": "limited",
#             "wikidata": "Q1126258",
#             "wikipedia": "en:Stanley Park"
#          }
#       }
#    ]
# }

# %%
print(park_way["elements"][0]["tags"]["wikipedia"])
# Out:
# en:Stanley Park

# %%
url_template = "http://dbpedia.org/data/{concept}.{format}"
concept = park_way["elements"][0]["tags"]["wikipedia"].replace(" ", "_")\
                                                        .replace("en:", "")
format = "jsod"

url = url_template.replace("{concept}", concept)\
                  .replace("{format}", format)

data = requests.get(url)
park_dbpedia = data.json()
print(json.dumps(park_dbpedia, indent=3))
# Out:
# {
#    "d": {
#       "results": [
#          {
#             "__metadata": {
#                "uri": "http://dbpedia.org/resource/Stanley_Park"
#             },
#             "http://dbpedia.org/ontology/wikiPageWikiLink": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Salmon"
#                }
#             },
#             "http://www.w3.org/1999/02/22-rdf-syntax-ns#type": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/class/yago/Facility103315023"
#                }
#             },
#             "http://dbpedia.org/property/wikiPageUsesTemplate": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Template:Vancouver_landmarks"
#                }
#             },
#             "http://xmlns.com/foaf/0.1/depiction": {
#                "__deferred": {
#                   "uri": "http://commons.wikimedia.org/wiki/Special:FilePath/Stanley_Park_SqueakyMarmot_December_17,_2006.jpg"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageExternalLink": {
#                "__deferred": {
#                   "uri": "http://onthisspot.ca/stanleypark.html"
#                }
#             },
#             "http://www.w3.org/2000/01/rdf-schema#comment": "Stanley Park \u00e4r en 404,9 hektar stor park i Vancouver i Kanada. Den invigdes 1888 av Lord Stanley of Preston, generalguvern\u00f6r i Kanada.",
#             "http://purl.org/dc/terms/subject": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Category:National_Historic_Sites_in_British_Columbia"
#                }
#             },
#             "http://dbpedia.org/property/name": "Stanley Park",
#             "http://www.w3.org/2002/07/owl#sameAs": {
#                "__deferred": {
#                   "uri": "http://www.wikidata.org/entity/Q1126258"
#                }
#             },
#             "http://www.w3.org/2000/01/rdf-schema#label": "Stanley Park",
#             "http://dbpedia.org/ontology/abstract": "Stanley Park \u00e4r en 404,9 hektar stor park i Vancouver i Kanada. Den invigdes 1888 av Lord Stanley of Preston, generalguvern\u00f6r i Kanada.",
#             "http://dbpedia.org/property/photoWidth": "275",
#             "http://www.georss.org/georss/point": "49.3 -123.14",
#             "http://dbpedia.org/property/caption": "2017",
#             "http://dbpedia.org/property/height": "250",
#             "http://dbpedia.org/property/visitationNum": "8000000",
#             "http://www.w3.org/ns/prov#wasDerivedFrom": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Stanley_Park?oldid=1021718409&ns=0"
#                }
#             },
#             "http://dbpedia.org/property/location": "Vancouver, British Columbia, Canada",
#             "http://dbpedia.org/ontology/wikiPageID": "292741",
#             "http://www.w3.org/2003/01/geo/wgs84_pos#long": "-123.1399993896484",
#             "http://dbpedia.org/ontology/thumbnail": {
#                "__deferred": {
#                   "uri": "http://commons.wikimedia.org/wiki/Special:FilePath/Stanley_Park_SqueakyMarmot_December_17,_2006.jpg?width=300"
#                }
#             },
#             "http://www.w3.org/2003/01/geo/wgs84_pos#geometry": "POINT(-123.13999938965 49.299999237061)",
#             "http://www.w3.org/2003/01/geo/wgs84_pos#lat": "49.29999923706055",
#             "http://dbpedia.org/ontology/location": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Canada"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageLength": "67420",
#             "http://dbpedia.org/ontology/wikiPageRevisionID": "1021718409",
#             "http://xmlns.com/foaf/0.1/isPrimaryTopicOf": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Stanley_Park"
#                }
#             },
#             "http://dbpedia.org/property/photo": "Stanley Park Labeled Aerial Map.png",
#             "http://dbpedia.org/property/operator": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Vancouver_Park_Board"
#                }
#             },
#             "http://dbpedia.org/property/alt": "Panorama view of Lost Lagoon in 2017",
#             "http://dbpedia.org/property/type": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Urban_park"
#                }
#             },
#             "http://dbpedia.org/property/photoCaption": "Aerial view of Stanley Park",
#             "http://dbpedia.org/ontology/type": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Urban_park"
#                }
#             },
#             "http://dbpedia.org/property/created": "1888",
#             "http://purl.org/linguistics/gold/hypernym": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Areas"
#                }
#             }
#          }
#       ],
#       "__count": "1"
#    }
# }
